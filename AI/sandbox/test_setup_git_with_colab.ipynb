# %%
# connecting colab to google drive by mounting
# this makes my files available to the notebook
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# navigate to my drive directory
# %cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# setup github variables
username = "TechLabs-Berlin"
repository = "wt23-wastewise"
git_token = "*****" # censored lol

# %%
# clone the wastewise github repo
#!git clone https://{git_token}@github.com/{username}/{repository}

# outcommented, because only necessary to clone once

# link to repo:
# https://github.com/TechLabs-Berlin/wt23-wastewise.git
# Out:
# Cloning into 'wt23-wastewise'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 84 (delta 26), reused 42 (delta 8), pack-reused 0
# Unpacking objects: 100% (84/84), 71.61 KiB | 61.00 KiB/s, done.

# %%
# navigate to the AI subdirectory
# %cd wt23-wastewise/
# Out:
# /content/drive/MyDrive/wt23-wastewise

# %%
# do not work in main! -> switch to remote branch data_preparation_DL
# !git switch data_preparation_DL
# Out:
# Already on 'data_preparation_DL'
# Your branch is up to date with 'origin/data_preparation_DL'.

# %%
# see if it worked
# !git status
# Out:
# On branch data_preparation_DL
# Your branch is up to date with 'origin/data_preparation_DL'.
#
# nothing to commit, working tree clean

# %%
# it worked. However, the remote branch was not up to date
# -> get all available updated, on all branches, then merge main into data_preparation_DL
# !git fetch --all
# !git merge main
# Out:
# Fetching origin
# Updating 82d332b..9c8778a
# Fast-forward
#  .../brainstorm_data_preparation.md                 |  0
#  AI/README.md                                       |  1 +
#  DS/README.md                                       |  1 +
#  DS/Recycling rate waste.ipynb                      |  1 +
#  UX/README.md                                       |  1 +
#  WD/README.md                                       |  1 +
#  WD/playground/startscreen.css                      | 55 ++++++++++++++++++++++
#  WD/playground/startscreen.html                     | 27 +++++++++++
#  app/README.md                                      |  1 +
#  9 files changed, 88 insertions(+)
#  rename {DL_data_preparation => AI/DL_data_preparation}/brainstorm_data_preparation.md (100%)
#  create mode 100644 AI/README.md
#  create mode 100644 DS/README.md
#  create mode 100644 DS/Recycling rate waste.ipynb
#  create mode 100644 UX/README.md
#  create mode 100644 WD/README.md
#  create mode 100644 WD/playground/startscreen.css
#  create mode 100644 WD/playground/startscreen.html
#  create mode 100644 app/README.md

# %%
# check once more if everything went fine
# !git status
# Out:
# On branch data_preparation_DL
# Your branch is ahead of 'origin/data_preparation_DL' by 11 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# make sure I am in the right directory
# %pwd
# Out:
# '/content/drive/MyDrive/wt23-wastewise'

# %%
# go to our AI directory
# %cd AI
# Out:
# /content/drive/MyDrive/wt23-wastewise/AI

# %%
# make a new directory for testing out stuff like this
# then change to that new directory and create a README.md file to clarify what's happening here
# %mkdir sandbox
# %cd sandbox
# !touch README.md # fill this file using vs code later on
# Out:
# /content/drive/MyDrive/wt23-wastewise/AI/sandbox

# %%
# save this notebook to drive using the colab GUI, then move it to the newly created sandbox directory

# %%
# check some git again
# !git status
# Out:
# On branch data_preparation_DL
# Your branch is ahead of 'origin/data_preparation_DL' by 11 commits.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	./
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# stage everything
# !git add .

# %%
# !git status
# Out:
# On branch data_preparation_DL
# Your branch is ahead of 'origin/data_preparation_DL' by 11 commits.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   README.md
# 	new file:   test_setup_git_with_colab.ipynb

# %%
# configure git first.
# !git config --global user.email "fabianjkrueger@yahoo.de"
# !git config --global user.name "fabianjkrueger"

# %%
# commit and include a descriptive message :)
# !git commit -m "Made a new sandbox directory for trying out stuff regarding the setup of colab, drive and github for the actual project. Added some files and experimented a little."
# Out:
# [data_preparation_DL 69edbc8] Made a new sandbox directory for trying out stuff regarding the setup of colab, drive and github for the actual project. Added some files and experimented a little.
#  2 files changed, 1 insertion(+)
#  create mode 100644 AI/sandbox/README.md
#  create mode 100644 AI/sandbox/test_setup_git_with_colab.ipynb

# %%
# !git status
# Out:
# On branch data_preparation_DL
# Your branch is ahead of 'origin/data_preparation_DL' by 12 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
git remote add origin https://{username}:{password}@github.com/{username}/project.git

# %%
# !git remote add origin https://{username}:{password}@github.com/{username}/project.git
# Out:
# fatal: remote origin already exists.
