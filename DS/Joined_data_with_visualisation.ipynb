# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
# %cd drive/MyDrive/TechLabs/02_Data\ Manipulation/Part\ C\ -\ Pandas
# Out:
# /content/drive/MyDrive/TechLabs/02_Data Manipulation/Part C - Pandas

# %%
# This is the convention used to import Pandas.
import pandas as pd
import numpy as np

# %%
waste = pd.read_csv("data/cei_pc031_page_linear.csv")
recycle = pd.read_csv("data/sdg_11_60_page_linear.csv")

# %%
#Dataset 1: Generation of municipal waste per capita in kg (Europe)
waste.head()
# Out:
#                DATAFLOW        LAST UPDATE freq wst_oper    unit geo  \
# 0  ESTAT:CEI_PC031(1.0)  17/02/23 23:00:00    A      GEN  KG_HAB  AL
# 1  ESTAT:CEI_PC031(1.0)  17/02/23 23:00:00    A      GEN  KG_HAB  AL
# 2  ESTAT:CEI_PC031(1.0)  17/02/23 23:00:00    A      GEN  KG_HAB  AL
# 3  ESTAT:CEI_PC031(1.0)  17/02/23 23:00:00    A      GEN  KG_HAB  AL
# 4  ESTAT:CEI_PC031(1.0)  17/02/23 23:00:00    A      GEN  KG_HAB  AL
#
#    TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0         2013        325        s
# 1         2014        425        s
# 2         2015        491        s
# 3         2016        452        e
# 4         2017        436        e

# %%
#Dataset 2: Recycling rate of municipal waste in % (Europe)
recycle.head()
# Out:
#                DATAFLOW        LAST UPDATE freq unit geo  TIME_PERIOD  \
# 0  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AL         2020
# 1  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AL         2021
# 2  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AT         2000
# 3  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AT         2001
# 4  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AT         2002
#
#    OBS_VALUE OBS_FLAG
# 0       18.1      NaN
# 1       18.7      NaN
# 2       63.4      NaN
# 3       64.3        e
# 4       62.5        e

# %%
#delete irrelevant columns for the data analysis from both datasets
waste.drop("DATAFLOW", inplace=True, axis=1)
waste.drop("LAST UPDATE", inplace=True, axis=1)
waste.drop("freq", inplace=True, axis=1)
waste.drop("wst_oper", inplace=True, axis=1)
waste.drop("unit", inplace=True, axis=1)
waste.drop("OBS_FLAG", inplace=True, axis=1)
recycle.drop("DATAFLOW", inplace=True, axis=1)
recycle.drop("LAST UPDATE", inplace=True, axis=1)
recycle.drop("freq", inplace=True, axis=1)
recycle.drop("unit", inplace=True, axis=1)
recycle.drop("OBS_FLAG", inplace=True, axis=1)

# %%
#rename columns in both datasets
waste.rename(columns={"geo": "region_id", "TIME_PERIOD":"year", "OBS_VALUE":"municipal_waste_per_capita_kg"}, inplace=True)
recycle.rename(columns={"geo": "region_id", "TIME_PERIOD":"year", "OBS_VALUE":"recycling_rate_municipal_waste_percent"}, inplace=True)

# %%
#unique values of series object ["region_id"] for Dataset 1
waste["region_id"].unique()
# Out:
# array(['AL', 'AT', 'BA', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE',
#        'EL', 'ES', 'EU27_2020', 'FI', 'FR', 'HR', 'HU', 'IE', 'IS', 'IT',
#        'LT', 'LU', 'LV', 'ME', 'MK', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO',
#        'RS', 'SE', 'SI', 'SK', 'TR', 'UK', 'XK'], dtype=object)

# %%
waste["region_id"].nunique()
# Out:
# 39

# %%
#unique values of series object ["region_id"] for Dataset 2
recycle["region_id"].unique()
# Out:
# array(['AL', 'AT', 'BA', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE',
#        'EL', 'ES', 'EU27_2020', 'FI', 'FR', 'HR', 'HU', 'IE', 'IS', 'IT',
#        'LT', 'LU', 'LV', 'ME', 'MK', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO',
#        'RS', 'SE', 'SI', 'SK', 'TR', 'UK', 'XK'], dtype=object)

# %%
recycle["region_id"].nunique()
# Out:
# 39

# %%
#add a new column and assign the country name to it: Dataset 1
waste["country_name"]=waste.region_id.replace({"EU27_2020": "European Union - 27 countries (from 2020)",
"BE": "Belgium",
"BG": "Bulgaria",
"CZ": "Czechia",
"DK": "Denmark",
"DE": "Germany",
"EE": "Estonia",
"IE": "Ireland",
"EL": "Greece",
"ES": "Spain",
"FR": "France",
"HR": "Croatia",
"CY": "Cyprus",
"IT": "Italy",
"IS": "Iceland",
"LV": "Latvia",
"LT": "Lithuania",
"LU": "Luxembourg",
"HU": "Hungary",
"MT": "Malta",
"NL": "Netherlands",
"AT": "Austria",
"PL": "Poland",
"PT": "Portugal",
"RO": "Romania",
"SI": "Slovenia",
"SK": "Slovakia",
"FI": "Finland",
"SE": "Sweden",
"IS": "Iceland",
"LI": "Lichtenstein",
"NO": "Norway",
"CH": "Switzerland",
"UK": "United Kingdom",
"BA": "Bosnia and Herzegovina",
"ME": "Montenegro",
"MK": "North Macedonia",
"AL": "Albania",
"RS": "Serbia",
"TR": "Türkiye",
"XK": "Kosovo (under United Nations Security Council Resolution 1244/99)"
})

# %%
#add a new column and assign the country name to it: Dataset 2
recycle["country_name"]=recycle.region_id.replace({"EU27_2020": "European Union - 27 countries (from 2020)",
"BE": "Belgium",
"BG": "Bulgaria",
"CZ": "Czechia",
"DK": "Denmark",
"DE": "Germany",
"EE": "Estonia",
"IE": "Ireland",
"EL": "Greece",
"ES": "Spain",
"FR": "France",
"HR": "Croatia",
"CY": "Cyprus",
"IT": "Italy",
"LV": "Latvia",
"LT": "Lithuania",
"LU": "Luxembourg",
"HU": "Hungary",
"MT": "Malta",
"NL": "Netherlands",
"AT": "Austria",
"PL": "Poland",
"PT": "Portugal",
"RO": "Romania",
"ST": "Slovenia",
"SK": "Slovakia",
"FI": "Finland",
"SE": "Sweden",
"SI": "Iceland",
"NO": "Norway",
"CH": "Switzerland",
"UK": "United Kingdom",
"BA": "Bosnia and Herzegovina",
"ME": "Montenegro",
"MK": "North Macedonia",
"AL": "Albania",
"RS": "Serbia",
"TR": "Türkiye",
"XK": "Kosovo (under United Nations Security Council Resolution 1244/99)"
})

# %%
#INNER JOIN between 2 DataFrames--> set of records that have a mutual value in the specified joining column(s)
joined=waste.merge(recycle, on =["country_name", "region_id", "year"])
joined.head(30)
# Out:
#    region_id  year  municipal_waste_per_capita_kg            country_name  \
# 0         AL  2020                            369                 Albania
# 1         AL  2021                            311                 Albania
# 2         AT  2000                            580                 Austria
# 3         AT  2001                            576                 Austria
# 4         AT  2002                            608                 Austria
# 5         AT  2003                            607                 Austria
# 6         AT  2004                            574                 Austria
# 7         AT  2005                            575                 Austria
# 8         AT  2006                            597                 Austria
# 9         AT  2007                            597                 Austria
# 10        AT  2008                            600                 Austria
# 11        AT  2009                            590                 Austria
# 12        AT  2010                            562                 Austria
# 13        AT  2011                            573                 Austria
# 14        AT  2012                            579                 Austria
# 15        AT  2013                            578                 Austria
# 16        AT  2014                            565                 Austria
# 17        AT  2015                            560                 Austria
# 18        AT  2016                            564                 Austria
# 19        AT  2017                            570                 Austria
# 20        AT  2018                            579                 Austria
# 21        AT  2019                            588                 Austria
# 22        AT  2020                            834                 Austria
# 23        BA  2008                            356  Bosnia and Herzegovina
# 24        BA  2009                            354  Bosnia and Herzegovina
# 25        BA  2010                            332  Bosnia and Herzegovina
# 26        BA  2011                            340  Bosnia and Herzegovina
# 27        BA  2012                            340  Bosnia and Herzegovina
# 28        BA  2013                            311  Bosnia and Herzegovina
# 29        BA  2014                            349  Bosnia and Herzegovina
#
#     recycling_rate_municipal_waste_percent
# 0                                     18.1
# 1                                     18.7
# 2                                     63.4
# 3                                     64.3
# 4                                     62.5
# 5                                     64.2
# 6                                     57.4
# 7                                     58.3
# 8                                     59.2
# 9                                     60.2
# 10                                    63.2
# 11                                    61.9
# 12                                    59.4
# 13                                    56.7
# 14                                    57.7
# 15                                    57.7
# 16                                    56.3
# 17                                    56.9
# 18                                    57.6
# 19                                    57.8
# 20                                    57.7
# 21                                    58.2
# 22                                    62.3
# 23                                     0.0
# 24                                     0.0
# 25                                     0.0
# 26                                     0.0
# 27                                     0.0
# 28                                     0.0
# 29                                     0.0

# %%
#move the column ["country_name"] before ["region_id"]
column_to_move = joined.pop("country_name")
joined.insert(0, "country_name", column_to_move)
joined.head()
# Out:
#   country_name region_id  year  municipal_waste_per_capita_kg  \
# 0      Albania        AL  2020                            369
# 1      Albania        AL  2021                            311
# 2      Austria        AT  2000                            580
# 3      Austria        AT  2001                            576
# 4      Austria        AT  2002                            608
#
#    recycling_rate_municipal_waste_percent
# 0                                    18.1
# 1                                    18.7
# 2                                    63.4
# 3                                    64.3
# 4                                    62.5

# %%
#replace zero value with NAN
joined.replace(0, np.nan, inplace=True)
joined.head(30)
# Out:
#               country_name region_id  year  municipal_waste_per_capita_kg  \
# 0                  Albania        AL  2020                            369
# 1                  Albania        AL  2021                            311
# 2                  Austria        AT  2000                            580
# 3                  Austria        AT  2001                            576
# 4                  Austria        AT  2002                            608
# 5                  Austria        AT  2003                            607
# 6                  Austria        AT  2004                            574
# 7                  Austria        AT  2005                            575
# 8                  Austria        AT  2006                            597
# 9                  Austria        AT  2007                            597
# 10                 Austria        AT  2008                            600
# 11                 Austria        AT  2009                            590
# 12                 Austria        AT  2010                            562
# 13                 Austria        AT  2011                            573
# 14                 Austria        AT  2012                            579
# 15                 Austria        AT  2013                            578
# 16                 Austria        AT  2014                            565
# 17                 Austria        AT  2015                            560
# 18                 Austria        AT  2016                            564
# 19                 Austria        AT  2017                            570
# 20                 Austria        AT  2018                            579
# 21                 Austria        AT  2019                            588
# 22                 Austria        AT  2020                            834
# 23  Bosnia and Herzegovina        BA  2008                            356
# 24  Bosnia and Herzegovina        BA  2009                            354
# 25  Bosnia and Herzegovina        BA  2010                            332
# 26  Bosnia and Herzegovina        BA  2011                            340
# 27  Bosnia and Herzegovina        BA  2012                            340
# 28  Bosnia and Herzegovina        BA  2013                            311
# 29  Bosnia and Herzegovina        BA  2014                            349
#
#     recycling_rate_municipal_waste_percent
# 0                                     18.1
# 1                                     18.7
# 2                                     63.4
# 3                                     64.3
# 4                                     62.5
# 5                                     64.2
# 6                                     57.4
# 7                                     58.3
# 8                                     59.2
# 9                                     60.2
# 10                                    63.2
# 11                                    61.9
# 12                                    59.4
# 13                                    56.7
# 14                                    57.7
# 15                                    57.7
# 16                                    56.3
# 17                                    56.9
# 18                                    57.6
# 19                                    57.8
# 20                                    57.7
# 21                                    58.2
# 22                                    62.3
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN

# %%
#delete missing values
joined.dropna(inplace=True)
joined.head(40)
# Out:
#    country_name region_id  year  municipal_waste_per_capita_kg  \
# 0       Albania        AL  2020                            369
# 1       Albania        AL  2021                            311
# 2       Austria        AT  2000                            580
# 3       Austria        AT  2001                            576
# 4       Austria        AT  2002                            608
# 5       Austria        AT  2003                            607
# 6       Austria        AT  2004                            574
# 7       Austria        AT  2005                            575
# 8       Austria        AT  2006                            597
# 9       Austria        AT  2007                            597
# 10      Austria        AT  2008                            600
# 11      Austria        AT  2009                            590
# 12      Austria        AT  2010                            562
# 13      Austria        AT  2011                            573
# 14      Austria        AT  2012                            579
# 15      Austria        AT  2013                            578
# 16      Austria        AT  2014                            565
# 17      Austria        AT  2015                            560
# 18      Austria        AT  2016                            564
# 19      Austria        AT  2017                            570
# 20      Austria        AT  2018                            579
# 21      Austria        AT  2019                            588
# 22      Austria        AT  2020                            834
# 33      Belgium        BE  2000                            471
# 34      Belgium        BE  2001                            467
# 35      Belgium        BE  2002                            482
# 36      Belgium        BE  2003                            465
# 37      Belgium        BE  2004                            485
# 38      Belgium        BE  2005                            482
# 39      Belgium        BE  2006                            485
# 40      Belgium        BE  2007                            493
# 41      Belgium        BE  2008                            480
# 42      Belgium        BE  2009                            467
# 43      Belgium        BE  2010                            456
# 44      Belgium        BE  2011                            455
# 45      Belgium        BE  2012                            445
# 46      Belgium        BE  2013                            436
# 47      Belgium        BE  2014                            425
# 48      Belgium        BE  2015                            412
# 49      Belgium        BE  2016                            419
#
#     recycling_rate_municipal_waste_percent
# 0                                     18.1
# 1                                     18.7
# 2                                     63.4
# 3                                     64.3
# 4                                     62.5
# 5                                     64.2
# 6                                     57.4
# 7                                     58.3
# 8                                     59.2
# 9                                     60.2
# 10                                    63.2
# 11                                    61.9
# 12                                    59.4
# 13                                    56.7
# 14                                    57.7
# 15                                    57.7
# 16                                    56.3
# 17                                    56.9
# 18                                    57.6
# 19                                    57.8
# 20                                    57.7
# 21                                    58.2
# 22                                    62.3
# 33                                    49.7
# 34                                    50.4
# 35                                    51.5
# 36                                    52.9
# 37                                    53.5
# 38                                    55.6
# 39                                    56.1
# 40                                    56.8
# 41                                    52.7
# 42                                    53.9
# 43                                    54.8
# 44                                    54.4
# 45                                    53.4
# 46                                    52.8
# 47                                    53.8
# 48                                    53.5
# 49                                    53.5

# %%
joined.isna()
# Out:
#      country_name  region_id   year  municipal_waste_per_capita_kg  \
# 0           False      False  False                          False
# 1           False      False  False                          False
# 2           False      False  False                          False
# 3           False      False  False                          False
# 4           False      False  False                          False
# ..            ...        ...    ...                            ...
# 672         False      False  False                          False
# 673         False      False  False                          False
# 674         False      False  False                          False
# 675         False      False  False                          False
# 676         False      False  False                          False
#
#      recycling_rate_municipal_waste_percent
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ..                                      ...
# 672                                   False
# 673                                   False
# 674                                   False
# 675                                   False
# 676                                   False
#
# [652 rows x 5 columns]

# %%
pd.options.display.max_rows = 100
joined
# Out:
#        country_name region_id  year  municipal_waste_per_capita_kg  \
# 0           Albania        AL  2020                            369
# 1           Albania        AL  2021                            311
# 2           Austria        AT  2000                            580
# 3           Austria        AT  2001                            576
# 4           Austria        AT  2002                            608
# ..              ...       ...   ...                            ...
# 672  United Kingdom        UK  2014                            482
# 673  United Kingdom        UK  2015                            483
# 674  United Kingdom        UK  2016                            483
# 675  United Kingdom        UK  2017                            468
# 676  United Kingdom        UK  2018                            463
#
#      recycling_rate_municipal_waste_percent
# 0                                      18.1
# 1                                      18.7
# 2                                      63.4
# 3                                      64.3
# 4                                      62.5
# ..                                      ...
# 672                                    43.4
# 673                                    43.3
# 674                                    44.0
# 675                                    43.8
# 676                                    44.1
#
# [652 rows x 5 columns]

# %%
joined["row_num"]=np.arange(1, len(joined)+1)
joined
# Out:
#        country_name region_id  year  municipal_waste_per_capita_kg  \
# 0           Albania        AL  2020                            369
# 1           Albania        AL  2021                            311
# 2           Austria        AT  2000                            580
# 3           Austria        AT  2001                            576
# 4           Austria        AT  2002                            608
# ..              ...       ...   ...                            ...
# 672  United Kingdom        UK  2014                            482
# 673  United Kingdom        UK  2015                            483
# 674  United Kingdom        UK  2016                            483
# 675  United Kingdom        UK  2017                            468
# 676  United Kingdom        UK  2018                            463
#
#      recycling_rate_municipal_waste_percent  row_num
# 0                                      18.1        1
# 1                                      18.7        2
# 2                                      63.4        3
# 3                                      64.3        4
# 4                                      62.5        5
# ..                                      ...      ...
# 672                                    43.4      648
# 673                                    43.3      649
# 674                                    44.0      650
# 675                                    43.8      651
# 676                                    44.1      652
#
# [652 rows x 6 columns]

# %%
#sorting by ["year"]
joined.sort_values(by="year", ascending = True, inplace=True)
joined.head()
# Out:
#        country_name region_id  year  municipal_waste_per_capita_kg  \
# 609          Sweden        SE  2000                            425
# 120         Czechia        CZ  2000                            335
# 271         Finland        FI  2000                            502
# 485     Netherlands        NL  2000                            598
# 658  United Kingdom        UK  2000                            577
#
#      recycling_rate_municipal_waste_percent  row_num
# 609                                    38.5      585
# 120                                     0.9      111
# 271                                    33.6      262
# 485                                    44.1      469
# 658                                    11.1      634

# %%
# %matplotlib inline
import seaborn as sns  #for plotting
sns.set_style("darkgrid")
import matplotlib.pyplot as plt # for showing plots
from scipy import stats

# %%
from scipy.stats import pearsonr
joined_plot = joined[["municipal_waste_per_capita_kg","recycling_rate_municipal_waste_percent"]].dropna()
#determine the annotation's position
r = "r = " + str(round(pearsonr(joined_plot["municipal_waste_per_capita_kg"], joined_plot["recycling_rate_municipal_waste_percent"])[0], 2))
sns.kdeplot(data=joined, x= "municipal_waste_per_capita_kg", y="recycling_rate_municipal_waste_percent",  fill = True).annotate(r, xy=(50, 50), xycoords="data");

# %%
#check the correlation (0.45 is medium, ok)
joined["municipal_waste_per_capita_kg"].corr(joined["recycling_rate_municipal_waste_percent"])
# Out:
# 0.4467410572847335

# %%
#plot Dataset 1
sns.lineplot(x="year", y="municipal_waste_per_capita_kg", data = joined)
plt.title('Municipal waste per capita (kg) in Europe')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plot Dataset 2
sns.lineplot(x="year", y="recycling_rate_municipal_waste_percent", data = joined)
plt.title('Municipal recycling rate (%) in Europe')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
! pip install jupyter-dash
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jupyter-dash
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: flask in /usr/local/lib/python3.8/dist-packages (from jupyter-dash) (2.2.3)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.8/dist-packages (from jupyter-dash) (5.3.4)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from jupyter-dash) (7.9.0)
# Collecting dash
#   Downloading dash-2.8.1-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 47.6 MB/s eta 0:00:00
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from jupyter-dash) (2.25.1)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from dash->jupyter-dash) (5.5.0)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.8/dist-packages (from flask->jupyter-dash) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.8/dist-packages (from flask->jupyter-dash) (2.2.3)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.8/dist-packages (from flask->jupyter-dash) (8.1.3)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.8/dist-packages (from flask->jupyter-dash) (3.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.8/dist-packages (from flask->jupyter-dash) (6.0.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from ipykernel->jupyter-dash) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel->jupyter-dash) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel->jupyter-dash) (6.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->jupyter-dash) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->jupyter-dash) (4.4.2)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.5 MB/s eta 0:00:00
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->jupyter-dash) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->jupyter-dash) (57.4.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->jupyter-dash) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->jupyter-dash) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->jupyter-dash) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->jupyter-dash) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->jupyter-dash) (2022.12.7)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from retrying->jupyter-dash) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=3.6.0->flask->jupyter-dash) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from Jinja2>=3.0->flask->jupyter-dash) (2.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.2.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.6)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.8/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (23.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.8/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (5.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter-dash) (3.0.0)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, retrying, nest-asyncio, jedi, ansi2html, dash, jupyter-dash
# Successfully installed ansi2html-1.8.0 dash-2.8.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 jedi-0.18.2 jupyter-dash-0.4.2 nest-asyncio-1.5.6 retrying-1.3.4

# %%
from jupyter_dash import JupyterDash
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Output, Input
import plotly.graph_objects as go
import plotly.express as px
# Out:
# <ipython-input-29-5a9b5e11e5c1>:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# <ipython-input-29-5a9b5e11e5c1>:4: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc

# %%
#a bar chart with a year-dropdown for Dataset 1
app = JupyterDash(__name__)


app.layout = html.Div([
    html.Header('Select the year:', style={"textAlign":"left"}),
    dcc.Dropdown(id='year_dropdown',
                 options= joined["year"].unique(),
                 value = 2000),
    dcc.Graph(id='waste_chart'),
])
   

@app.callback(Output("waste_chart", "figure"),
              Input("year_dropdown", "value"))
def sync_input(year_selection):
  #fix the height size to see all countries' names
  year_joined = joined[joined['year'] == 2002].sort_values('municipal_waste_per_capita_kg'
          , ascending=True)
  len_countries = len(year_joined["row_num"].unique())
  
  fig = px.bar(joined.loc[joined["year"]==year_selection].sort_values("municipal_waste_per_capita_kg", ascending=False),
               x="municipal_waste_per_capita_kg",
               y="country_name",
               height = 20 + (25*len_countries),
               title = f'Europe & Municipal waste generation per capita (kg) - Year {year_selection}',
  )
  fig.update_layout(yaxis_categoryorder='total ascending')
  
  return fig

app.run_server(mode="inline")

# %%
#a bar chart with a year-dropdown for Dataset 1
app = JupyterDash(__name__)


app.layout = html.Div([
    html.Header('Select the year:', style={"textAlign":"left"}),
    dcc.Dropdown(id='year_dropdown',
                 options= joined["year"].unique(),
                 value = 2000),
    dcc.Graph(id='recycle_chart'),
])
   

@app.callback(Output("recycle_chart", "figure"),
              Input("year_dropdown", "value"))
def sync_input(year_selection):
  #fix the height size to see all countries' names
  year_joined = joined[joined['year'] == 2002].sort_values('recycling_rate_municipal_waste_percent'
          , ascending=True)
  len_countries = len(year_joined["row_num"].unique())
  
  fig1 = px.bar(joined.loc[joined["year"]==year_selection].sort_values("recycling_rate_municipal_waste_percent", ascending=False),
               x="recycling_rate_municipal_waste_percent",
               y="country_name",
               height = 20 + (25*len_countries),
               title = f'Europe & Municipal recycling rate (%)- Year {year_selection}',
  )
  fig1.update_layout(yaxis_categoryorder='total ascending')
  
  return fig1

app.run_server(mode="inline")
