# %%
import pandas as pd

# %%
df
# Out:
#     age type_of_waste
# 0     5         Metal
# 1     7       Plastic
# 2    10         Paper
# 3    13         Glass
# 4    15       Organic
# 5    18         Metal
# 6    20         Paper
# 7    22       Plastic
# 8    25       Plastic
# 9    27         Glass
# 10   30       Plastic
# 11   33       Organic
# 12   35       Plastic
# 13   37       Organic
# 14   40         Glass
# 15   43       Organic
# 16   45         Glass
# 17   48       Organic
# 18   50       Plastic
# 19   53         Metal
# 20   55         Paper
# 21   57         Metal
# 22   60         Glass
# 23   62         Metal
# 24   65         Paper
# 25   68         Glass
# 26   70         Paper
# 27   73         Glass
# 28   75         Metal
# 29   78       Organic
# 30   80       Plastic
# 31   83         Glass
# 32   85         Glass
# 33   87       Organic
# 34   90       Plastic
# 35   93         Glass
# 36   95       Organic
# 37   98       Plastic
# 38   99       Organic

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import numpy as np

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['age'].values.reshape(-1, 1), df['type_of_waste'], test_size=0.2, random_state=42)

# Create and train a decision tree model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Make predictions on new ages
new_ages = np.array([[9], [14], [19], [24], [27], [34], [37], [44], [49], [54], [59], [64], [69], [74], [79], [84], [89], [94], [97], [101]])
predictions = model.predict(new_ages)

# Print the predictions
print(predictions)
# Out:
# ['Paper' 'Glass' 'Metal' 'Plastic' 'Glass' 'Organic' 'Plastic' 'Organic'
#  'Organic' 'Metal' 'Glass' 'Paper' 'Glass' 'Metal' 'Organic' 'Glass'
#  'Plastic' 'Glass' 'Plastic' 'Organic']
