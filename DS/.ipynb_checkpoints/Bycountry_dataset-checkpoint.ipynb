# %%
import pandas as pd
import numpy as np

# %%
bycountry = pd.read_csv("Databycountry.csv")

# %%
bycountry.head()
# Out:
#   iso3c region_id country_name income_id           gdp  \
# 0   ABW       LCN        Aruba       HIC  35563.312500
# 1   AFG       SAS  Afghanistan       LIC   2057.062256
# 2   AGO       SSF       Angola       LMC   8036.690430
# 3   ALB       ECS      Albania       UMC  13724.058594
# 4   AND       ECS      Andorra       HIC  43711.800781
#
#    composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                     NaN                        NaN
# 1                                     NaN                        NaN
# 2                                    51.8                        6.7
# 3                                    51.4                        4.5
# 4                                    31.2                        8.2
#
#    composition_metal_percent  composition_other_percent  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# ...

# %%
bycountry
# Out:
#     iso3c region_id  country_name income_id           gdp  \
# 0     ABW       LCN         Aruba       HIC  35563.312500
# 1     AFG       SAS   Afghanistan       LIC   2057.062256
# 2     AGO       SSF        Angola       LMC   8036.690430
# 3     ALB       ECS       Albania       UMC  13724.058594
# 4     AND       ECS       Andorra       HIC  43711.800781
# ..    ...       ...           ...       ...           ...
# 212   XKX       ECS        Kosovo       LMC   9723.561523
# 213   YEM       MEA   Yemen, Rep.       LIC   8269.671875
# 214   ZAF       SSF  South Africa       UMC  12666.607422
# 215   ZMB       SSF        Zambia       LMC   3201.289307
# 216   ZWE       SSF      Zimbabwe       LIC   3190.506592
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                       NaN                        NaN
# 1                                       NaN                        NaN
# ...

# %%
#Drop the columns that are not necessary for the analysis

bycountry.drop (columns=['iso3c', 
                         'region_id', 
                         'other_information_information_system_for_solid_waste_management',
                         'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
                         'other_information_national_law_governing_solid_waste_management_in_the_country', 
                         'other_information_ppp_rules_and_regulations',
                         'other_information_summary_of_key_solid_waste_information_made_available_to_the_public',
                         'special_waste_agricultural_waste_tons_year',
                         'special_waste_e_waste_tons_year',
                         'special_waste_hazardous_waste_tons_year',
                         'special_waste_industrial_waste_tons_year',
                         'special_waste_medical_waste_tons_year',
                         'waste_collection_coverage_rural_percent_of_geographic_area',
                         'waste_collection_coverage_rural_percent_of_households',
                         'waste_collection_coverage_rural_percent_of_population',
                         'waste_collection_coverage_rural_percent_of_waste',
                         'waste_collection_coverage_rural_percent_of_waste',
                         'waste_treatment_anaerobic_digestion_percent',
                         'waste_treatment_controlled_landfill_percent', 
                         'waste_treatment_incineration_percent',
                         'waste_treatment_landfill_unspecified_percent',
                         'waste_treatment_open_dump_percent', 
                         'waste_treatment_other_percent',
                         'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
                         'waste_treatment_unaccounted_for_percent',
                         'waste_treatment_waterways_marine_percent',
                         'where_where_is_this_data_measured'],inplace=True)

# %%
bycountry.columns
# Out:
# Index(['country_name', 'income_id', 'gdp',
#        'composition_food_organic_waste_percent', 'composition_glass_percent',
#        'composition_metal_percent', 'composition_other_percent',
#        'composition_paper_cardboard_percent', 'composition_plastic_percent',
#        'composition_rubber_leather_percent', 'composition_wood_percent',
#        'composition_yard_garden_green_waste_percent',
#        'population_population_number_of_people',
#        'special_waste_construction_and_demolition_waste_tons_year',
#        'total_msw_total_msw_generated_tons_year',
#        'waste_collection_coverage_total_percent_of_geographic_area',
#        'waste_collection_coverage_total_percent_of_households',
#        'waste_collection_coverage_total_percent_of_population',
#        'waste_collection_coverage_total_percent_of_waste',
#        'waste_collection_coverage_urban_percent_of_geographic_area',
#        'waste_collection_coverage_urban_percent_of_households',
# ...

# %%
#rename names of columns for better understanding


bycountry.rename(columns={'composition_food_organic_waste_percent': 'organic_food_percent', 
                           'composition_glass_percent': 'glass_percent', 
                           'composition_metal_percent': 'metal_percent',
                           'composition_other_percent': 'other_waste_percent',
                           'composition_paper_cardboard_percent': 'paper_cardboard_percent',
                           'composition_plastic_percent':'plastic_percent',
                           'composition_rubber_leather_percent': 'rubber_leather_percent',
                           'composition_wood_percent':'wood_percent',
                           'composition_yard_garden_green_waste_percent':'yard_garden_green_waste_percent',
                           'population_population_number_of_people': 'population_number_of_people',
                           'waste_collection_coverage_total_percent_of_geographic_area':'waste_collected_total_percent_geographic_area',
                           'waste_collection_coverage_urban_percent_of_households':'waste_collected_total_percent_of_households',
                           'waste_collection_coverage_total_percent_of_population': 'waste_collected_total_percent_of_popuation',
                           'waste_collection_coverage_urban_percent_of_waste': 'waste_collected_urban_percent_of_waste'} , inplace=True)

# %%
bycountry.head()
# Out:
#   country_name income_id           gdp  organic_food_percent  glass_percent  \
# 0        Aruba       HIC  35563.312500                   NaN            NaN
# 1  Afghanistan       LIC   2057.062256                   NaN            NaN
# 2       Angola       LMC   8036.690430                  51.8            6.7
# 3      Albania       UMC  13724.058594                  51.4            4.5
# 4      Andorra       HIC  43711.800781                  31.2            8.2
#
#    metal_percent  other_waste_percent  paper_cardboard_percent  \
# 0            NaN                  NaN                      NaN
# 1            NaN                  NaN                      NaN
# 2            4.4                11.50                     11.9
# 3            4.8                15.21                      9.9
# 4            2.6                11.60                     35.1
#
#    plastic_percent  rubber_leather_percent  ...  \
# 0              NaN                     NaN  ...
# ...

# %%
bycountry.isna()
# Out:
#      country_name  income_id    gdp  organic_food_percent  glass_percent  \
# 0           False      False  False                  True           True
# 1           False      False  False                  True           True
# 2           False      False  False                 False          False
# 3           False      False  False                 False          False
# 4           False      False  False                 False          False
# ..            ...        ...    ...                   ...            ...
# 212         False      False  False                 False          False
# 213         False      False  False                 False          False
# 214         False      False  False                 False          False
# 215         False      False  False                  True           True
# 216         False      False  False                 False          False
#
#      metal_percent  other_waste_percent  paper_cardboard_percent  \
# ...

# %%
#drop another column that I found is not necessary for the analysis

bycountry.drop (columns=['income_id'], inplace=True)

# %%
#create a new list to apply later in dropna to see if there is any country that has all the columns with missing values

new_list= list (bycountry.columns)

print(len(new_list))

new_list.remove('gdp')

new_list.remove('population_number_of_people')

new_list.remove('country_name')


print(new_list)

print(len(new_list))
# Out:
# 24
# ['organic_food_percent', 'glass_percent', 'metal_percent', 'other_waste_percent', 'paper_cardboard_percent', 'plastic_percent', 'rubber_leather_percent', 'wood_percent', 'yard_garden_green_waste_percent', 'special_waste_construction_and_demolition_waste_tons_year', 'total_msw_total_msw_generated_tons_year', 'waste_collected_total_percent_geographic_area', 'waste_collection_coverage_total_percent_of_households', 'waste_collected_total_percent_of_popuation', 'waste_collection_coverage_total_percent_of_waste', 'waste_collection_coverage_urban_percent_of_geographic_area', 'waste_collected_total_percent_of_households', 'waste_collection_coverage_urban_percent_of_population', 'waste_collected_urban_percent_of_waste', 'waste_treatment_compost_percent', 'waste_treatment_recycling_percent']
# 21

# %%
#applied dropna but no rows were droped
bycountry.dropna (subset = new_list, how = 'all', inplace=True)

# %%
bycountry
# Out:
#      country_name           gdp  organic_food_percent  glass_percent  \
# 0           Aruba  35563.312500                   NaN            NaN
# 1     Afghanistan   2057.062256                   NaN            NaN
# 2          Angola   8036.690430             51.800000       6.700000
# 3         Albania  13724.058594             51.400000       4.500000
# 4         Andorra  43711.800781             31.200000       8.200000
# ..            ...           ...                   ...            ...
# 212        Kosovo   9723.561523             42.000000       6.000000
# 213   Yemen, Rep.   8269.671875             65.000000       1.000000
# 214  South Africa  12666.607422             16.381655       5.200216
# 215        Zambia   3201.289307                   NaN            NaN
# 216      Zimbabwe   3190.506592             36.000000       5.000000
#
#      metal_percent  other_waste_percent  paper_cardboard_percent  \
# 0              NaN                  NaN                      NaN
# ...

# %%
#creating a new column to count all the NanN values in this.
bycountry["#ofNAN"]=bycountry.isnull().sum(axis=1)

# %%
#sorting the values to see the how many missing values has each country

bycountry.sort_values('#ofNAN', ascending= False)
# Out:
#                  country_name           gdp  organic_food_percent  \
# 31   Central African Republic    822.610474                   NaN
# 176               South Sudan   1795.991943                   NaN
# 165                    Rwanda   1950.528076                   NaN
# 51                   Djibouti   6596.775391                   NaN
# 174                   Somalia   1862.614136                   NaN
# ..                        ...           ...                   ...
# 150                  Pakistan   4571.414551                 30.00
# 91         Iran, Islamic Rep.  14535.862305                 72.90
# 53                    Denmark  57821.199219                 12.78
# 18                   Bulgaria  22279.361328                 24.35
# 127            Macedonia, FYR  16147.729492                 29.30
#
#      glass_percent  metal_percent  other_waste_percent  \
# 31             NaN            NaN                  NaN
# 176            NaN            NaN                  NaN
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
bycountry
# Out:
#      country_name           gdp  organic_food_percent  glass_percent  \
# 0           Aruba  35563.312500                   NaN            NaN
# 1     Afghanistan   2057.062256                   NaN            NaN
# 2          Angola   8036.690430             51.800000       6.700000
# 3         Albania  13724.058594             51.400000       4.500000
# 4         Andorra  43711.800781             31.200000       8.200000
# ..            ...           ...                   ...            ...
# 212        Kosovo   9723.561523             42.000000       6.000000
# 213   Yemen, Rep.   8269.671875             65.000000       1.000000
# 214  South Africa  12666.607422             16.381655       5.200216
# 215        Zambia   3201.289307                   NaN            NaN
# 216      Zimbabwe   3190.506592             36.000000       5.000000
#
#      metal_percent  other_waste_percent  paper_cardboard_percent  \
# 0              NaN                  NaN                      NaN
# ...

# %%
#drop another unnecesary column
bycountry.drop (columns=['total_msw_total_msw_generated_tons_year'],inplace=True)

# %%
#create an alternative data frame to see only organic food%; glass%; metal % ; other_waste % ; paper cardboard %;
#plastic %; population_number_of_people;#ofNaN


bycountry_produced=bycountry.drop (columns=[
                                    'rubber_leather_percent', 
                                    'wood_percent',
                                    'yard_garden_green_waste_percent', 
                                    'special_waste_construction_and_demolition_waste_tons_year',
                                    'waste_collected_total_percent_geographic_area',
                                    'waste_collection_coverage_total_percent_of_households',
                                    'waste_collected_total_percent_of_popuation',
                                    'waste_collection_coverage_total_percent_of_waste',
                                    'waste_collection_coverage_urban_percent_of_geographic_area',
                                    'waste_collected_total_percent_of_households',
                                    'waste_collection_coverage_urban_percent_of_population',
                                    'waste_collected_urban_percent_of_waste',
                                    'waste_treatment_compost_percent', 
                                    'waste_treatment_recycling_percent',
                                     '#ofNAN'])

# %%
bycountry_produced
# Out:
#      country_name           gdp  organic_food_percent  glass_percent  \
# 0           Aruba  35563.312500                   NaN            NaN
# 1     Afghanistan   2057.062256                   NaN            NaN
# 2          Angola   8036.690430             51.800000       6.700000
# 3         Albania  13724.058594             51.400000       4.500000
# 4         Andorra  43711.800781             31.200000       8.200000
# ..            ...           ...                   ...            ...
# 212        Kosovo   9723.561523             42.000000       6.000000
# 213   Yemen, Rep.   8269.671875             65.000000       1.000000
# 214  South Africa  12666.607422             16.381655       5.200216
# 215        Zambia   3201.289307                   NaN            NaN
# 216      Zimbabwe   3190.506592             36.000000       5.000000
#
#      metal_percent  other_waste_percent  paper_cardboard_percent  \
# 0              NaN                  NaN                      NaN
# ...

# %%
#check how many missing values has each country of this data frame 

bycountry_produced["#ofNAN"]=bycountry_produced.isnull().sum(axis=1)

# %%
bycountry_produced
# Out:
#      country_name           gdp  organic_food_percent  glass_percent  \
# 0           Aruba  35563.312500                   NaN            NaN
# 1     Afghanistan   2057.062256                   NaN            NaN
# 2          Angola   8036.690430             51.800000       6.700000
# 3         Albania  13724.058594             51.400000       4.500000
# 4         Andorra  43711.800781             31.200000       8.200000
# ..            ...           ...                   ...            ...
# 212        Kosovo   9723.561523             42.000000       6.000000
# 213   Yemen, Rep.   8269.671875             65.000000       1.000000
# 214  South Africa  12666.607422             16.381655       5.200216
# 215        Zambia   3201.289307                   NaN            NaN
# 216      Zimbabwe   3190.506592             36.000000       5.000000
#
#      metal_percent  other_waste_percent  paper_cardboard_percent  \
# 0              NaN                  NaN                      NaN
# ...

# %%
#sorting #ofNAN to see the countries wit more missing values

bycountry_produced.sort_values('#ofNAN', ascending= False)
# Out:
#              country_name           gdp  organic_food_percent  glass_percent  \
# 0                   Aruba  35563.312500                   NaN            NaN
# 180              Slovenia  39037.933594                   NaN            NaN
# 74          Guinea-Bissau   1800.068604                   NaN            NaN
# 159              Paraguay  11810.427734                   NaN            NaN
# 67                  Gabon  18514.652344                   NaN            NaN
# ..                    ...           ...                   ...            ...
# 82   Hong Kong SAR, China  57215.968750                  35.0           3.00
# 83               Honduras   5395.613770                  57.9           1.27
# 84                Croatia  28829.355469                  30.9           3.70
# 85                  Haiti   2952.618652                  61.3           1.60
# 216              Zimbabwe   3190.506592                  36.0           5.00
#
# ...

# %%
len(bycountry_produced.columns)
# Out:
# 10

# %%
#creating another data frame with only countries that have no missing values (Nan)

bycountry_produced_cleaned = bycountry_produced.dropna(thresh=10)

# %%
cleaned_country_list = bycountry_produced_cleaned["country_name"].to_list()
orig_country_list = bycountry["country_name"].to_list()

# %%
len(cleaned_country_list)
# Out:
# 159

# %%
len(orig_country_list)
# Out:
# 217

# %%
#countries that were dropped from the list as they had any or all missing values

set(orig_country_list).difference(set(cleaned_country_list))
# Out:
# {'Afghanistan',
#  'Aruba',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Cabo Verde',
#  'Central African Republic',
#  'Channel Islands',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Curacao',
#  'Côte d’Ivoire',
#  'Djibouti',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Eswatini',
#  'Faeroe Islands',
#  'Gabon',
#  'Gambia, The',
#  'Guatemala',
#  'Guinea-Bissau',
#  'Iceland',
#  'India',
#  'Isle of Man',
#  'Korea, Rep.',
#  'Kyrgyz Republic',
#  'Lesotho',
#  'Liberia',
#  'Madagascar',
#  'Malawi',
#  'Maldives',
#  'Mauritius',
#  'Monaco',
#  'Mongolia',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Oman',
#  'Papua New Guinea',
#  'Paraguay',
#  'Rwanda',
#  'Sierra Leone',
#  'Sint Maarten (Dutch part)',
#  'Slovenia',
#  'Somalia',
#  'South Sudan',
#  'St. Martin (French part)',
#  'Suriname',
#  'Sweden',
#  'São Tomé and Príncipe',
#  'Tajikistan',
#  'Tanzania',
#  'Turkmenistan',
#  'Venezuela, RB',
#  'Zambia',
# ...

# %%
#list of countries that don't have missing values

cleaned_country_list
# Out:
# ['Angola',
#  'Albania',
#  'Andorra',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas, The',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Canada',
#  'Switzerland',
#  'Chile',
#  'China',
#  'Cameroon',
#  'Colombia',
#  'Comoros',
#  'Costa Rica',
#  'Cuba',
#  'Cayman Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Dominica',
#  'Denmark',
#  'Dominican Republic',
#  'Algeria',
#  'Ecuador',
#  'Egypt, Arab Rep.',
#  'Spain',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'Fiji',
#  'France',
#  'Micronesia, Fed. Sts.',
#  'United Kingdom',
#  'Georgia',
#  'Ghana',
#  'Gibraltar',
#  'Guinea',
#  'Greece',
#  'Grenada',
#  'Greenland',
#  'Guam',
#  'Guyana',
# ...

# %%
bycountry_produced_cleaned
# Out:
#              country_name           gdp  organic_food_percent  glass_percent  \
# 2                  Angola   8036.690430             51.800000       6.700000
# 3                 Albania  13724.058594             51.400000       4.500000
# 4                 Andorra  43711.800781             31.200000       8.200000
# 5    United Arab Emirates  67119.132812             39.000000       4.000000
# 6               Argentina  23550.099609             38.740000       3.160000
# ..                    ...           ...                   ...            ...
# 211                 Samoa   6210.983398             42.600000       2.200000
# 212                Kosovo   9723.561523             42.000000       6.000000
# 213           Yemen, Rep.   8269.671875             65.000000       1.000000
# 214          South Africa  12666.607422             16.381655       5.200216
# 216              Zimbabwe   3190.506592             36.000000       5.000000
#
# ...

# %%
pd.reset_option('display.max_rows')

# %%
#checking if there are another missing value that I didn't see

bycountry_produced_cleaned.isna()
# Out:
#      country_name    gdp  organic_food_percent  glass_percent  metal_percent  \
# 2           False  False                 False          False          False
# 3           False  False                 False          False          False
# 4           False  False                 False          False          False
# 5           False  False                 False          False          False
# 6           False  False                 False          False          False
# ..            ...    ...                   ...            ...            ...
# 211         False  False                 False          False          False
# 212         False  False                 False          False          False
# 213         False  False                 False          False          False
# 214         False  False                 False          False          False
# 216         False  False                 False          False          False
#
# ...

# %%
bycountry_produced_cleaned

# %%
#create a new column with country code in order to later create a column with the name of the continent
#import packages to create a function 

import pycountry as pc

# %%
import country_converter as coco
import pycountry_convert as pc1

# %%
#create a function to create the continent column in the data frame


def country_to_continent(country_name):
    try:
        country_alpha2 = pc1.country_name_to_country_alpha2(country_name)
        country_continent_code = pc1.country_alpha2_to_continent_code(country_alpha2)
        country_continent_name = pc1.convert_continent_code_to_continent_name(country_continent_code)
    except:
        country_continent_name = ""
    return country_continent_name

# %%
#Creating the new column applying the country_to_continent function

bycountry_produced_cleaned['continents']= bycountry_produced_cleaned['country_name'].apply(country_to_continent)
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_19248\3493000295.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bycountry_produced_cleaned['continents']= bycountry_produced_cleaned['country_name'].apply(country_to_continent)

# %%
#check how many countries doesn't have continent applied
#my_filter = bycountry_produced_cleaned["continents"]==""

bycountry_produced_cleaned[bycountry_produced_cleaned["continents"]==""]
# Out:
#             country_name           gdp  organic_food_percent  glass_percent  \
# 192          Timor-Leste   3344.573730                  43.6            5.5
# 208  Virgin Islands U.S.  30436.564453                  46.0            7.0
#
#      metal_percent  other_waste_percent  paper_cardboard_percent  \
# 192           10.0                  9.3                     10.9
# 208            7.0                 12.0                     15.0
#
#      plastic_percent  population_number_of_people  #ofNAN continents  \
# 192             16.5                      1268671       0
# 208             13.0                       105784       0
#
#          continent
# 192           Asia
# 208  North America

# %%
#modify those countries to the correct name. You can see the correct names here https://en.wikipedia.org/wiki/ISO_3166-1_alpha-2

#East Timor instead of Timor-Leste
#Yemen
#Saint Vincent and the Grenadines
#Micronesia (Federated States of)
#Iran (Islamic Republic of)
#Lao People's Democratic Republic
#North Macedonia
#gaza to Palestine, State of


bycountry_produced_cleaned.loc[20,'country_name'] = 'Bahamas'

bycountry_produced_cleaned.loc[57,'country_name'] = 'Egypt'

bycountry_produced_cleaned.loc[66,'country_name'] = 'Micronesia'

bycountry_produced_cleaned.loc[82,'country_name'] = 'Hong Kong'

bycountry_produced_cleaned.loc[91,'country_name'] = 'Iran'

bycountry_produced_cleaned.loc[107,'country_name'] = "Lao People's Democratic Republic"

bycountry_produced_cleaned.loc[118,'country_name'] = "Macao"

bycountry_produced_cleaned.loc[127,'country_name'] = "North Macedonia"

bycountry_produced_cleaned.loc[160,'country_name'] = "Palestine, State of"

bycountry_produced_cleaned.loc[192,'country_name'] = "Timor-Leste"

bycountry_produced_cleaned.loc[205,'country_name'] = "Saint Vincent and the Grenadines"

bycountry_produced_cleaned.loc[208,'country_name'] = "Virgin Islands U.S."

bycountry_produced_cleaned.loc[213,'country_name'] = "Yemen"


#It's not being possible to get the continent of Timor-Leste and V irgin Islands U.S.so I will add it manually 

bycountry_produced_cleaned.loc[192,'continents'] = "Asia"

bycountry_produced_cleaned.loc[208, 'continents'] = "North America"

# %%
bycountry_produced_cleaned.loc[205]
# Out:
# country_name                   Saint Vincent and the Grenadines
# gdp                                                11971.993164
# organic_food_percent                                       49.6
# glass_percent                                               5.6
# metal_percent                                               3.8
# other_waste_percent                                        10.5
# paper_cardboard_percent                                    22.1
# plastic_percent                                             8.4
# population_number_of_people                              109455
# #ofNAN                                                        0
# continents
# Name: 205, dtype: object

# %%
#Drop kosovo as it's still unclear the country code as for some countries is not recognized yet

bycountry_produced_cleaned.drop (index =212, inplace= True)
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_19248\1993499564.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bycountry_produced_cleaned.drop (index =212, inplace= True)

# %%
bycountry_produced_cleaned
# Out:
#              country_name           gdp  organic_food_percent  glass_percent  \
# 2                  Angola   8036.690430             51.800000       6.700000
# 3                 Albania  13724.058594             51.400000       4.500000
# 4                 Andorra  43711.800781             31.200000       8.200000
# 5    United Arab Emirates  67119.132812             39.000000       4.000000
# 6               Argentina  23550.099609             38.740000       3.160000
# ..                    ...           ...                   ...            ...
# 210               Vanuatu   3061.787354             73.400000       5.400000
# 211                 Samoa   6210.983398             42.600000       2.200000
# 213                 Yemen   8269.671875             65.000000       1.000000
# 214          South Africa  12666.607422             16.381655       5.200216
# 216              Zimbabwe   3190.506592             36.000000       5.000000
#
# ...
